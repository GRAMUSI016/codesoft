# %% [markdown]
# <a href="https://colab.research.google.com/github/GRAMUSI016/codesoft/blob/main/Car_sales_predction(ANN%2C_Codesoft).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings("ignore")

print ('modules loaded')
# Out:
# modules loaded

# %% [markdown]
# Data Preprocessing

# %%
df = pd.read_csv('/content/sales_task4.csv', encoding='ISO-8859-1')

# Check the first few rows of the dataset
print(df.head())
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# 2  638467.1773          42925.70921
# 3  548599.0524          67422.36313
# 4  560304.0671          55915.46248

# %% [markdown]
# Drop unneeded columns

# %%
df.drop(columns=['customer name', 'customer e-mail', 'country', 'gender'], inplace=True)

# %% [markdown]
# Define X and y

# %%
X = df.drop('car purchase amount', axis=1)
y = df['car purchase amount']

# %% [markdown]
# Data Scaling

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(X)
y = scaler.fit_transform(y.values.reshape(-1, 1))

# %% [markdown]
# Data Splitting

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (400, 4)
# (400, 1)
# (100, 4)
# (100, 1)

# %% [markdown]
# Modal Structure

# %%
model = Sequential()
model.add(Dense(10, activation='relu', input_dim=4))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='linear'))

model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 10)                50
#
#  dense_4 (Dense)             (None, 10)                110
#
#  dense_5 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 171 (684.00 Byte)
# Trainable params: 171 (684.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Modal Training

# %%
history = model.fit(X_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 1s 20ms/step - loss: 0.1807 - mean_absolute_error: 0.3897 - val_loss: 0.1389 - val_mean_absolute_error: 0.3324
# Epoch 2/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0986 - mean_absolute_error: 0.2747 - val_loss: 0.0791 - val_mean_absolute_error: 0.2373
# Epoch 3/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0540 - mean_absolute_error: 0.1956 - val_loss: 0.0475 - val_mean_absolute_error: 0.1736
# Epoch 4/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0346 - mean_absolute_error: 0.1521 - val_loss: 0.0336 - val_mean_absolute_error: 0.1468
# Epoch 5/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0269 - mean_absolute_error: 0.1337 - val_loss: 0.0279 - val_mean_absolute_error: 0.1358
# Epoch 6/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0230 - mean_absolute_error: 0.1226 - val_loss: 0.0239 - val_mean_absolute_error: 0.1255
# Epoch 7/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0194 - mean_absolute_error: 0.1122 - val_loss: 0.0202 - val_mean_absolute_error: 0.1136
# Epoch 8/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0164 - mean_absolute_error: 0.1027 - val_loss: 0.0184 - val_mean_absolute_error: 0.1079
# Epoch 9/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0151 - mean_absolute_error: 0.0983 - val_loss: 0.0172 - val_mean_absolute_error: 0.1048
# Epoch 10/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0140 - mean_absolute_error: 0.0947 - val_loss: 0.0163 - val_mean_absolute_error: 0.1018
# Epoch 11/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0131 - mean_absolute_error: 0.0914 - val_loss: 0.0156 - val_mean_absolute_error: 0.0994
# Epoch 12/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0123 - mean_absolute_error: 0.0885 - val_loss: 0.0149 - val_mean_absolute_error: 0.0970
# Epoch 13/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0116 - mean_absolute_error: 0.0857 - val_loss: 0.0142 - val_mean_absolute_error: 0.0948
# Epoch 14/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0109 - mean_absolute_error: 0.0829 - val_loss: 0.0137 - val_mean_absolute_error: 0.0931
# Epoch 15/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0103 - mean_absolute_error: 0.0804 - val_loss: 0.0129 - val_mean_absolute_error: 0.0908
# Epoch 16/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0097 - mean_absolute_error: 0.0780 - val_loss: 0.0123 - val_mean_absolute_error: 0.0889
# Epoch 17/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0092 - mean_absolute_error: 0.0758 - val_loss: 0.0119 - val_mean_absolute_error: 0.0875
# Epoch 18/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0088 - mean_absolute_error: 0.0739 - val_loss: 0.0112 - val_mean_absolute_error: 0.0850
# Epoch 19/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0083 - mean_absolute_error: 0.0716 - val_loss: 0.0107 - val_mean_absolute_error: 0.0832
# Epoch 20/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0078 - mean_absolute_error: 0.0695 - val_loss: 0.0105 - val_mean_absolute_error: 0.0819
# Epoch 21/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0074 - mean_absolute_error: 0.0678 - val_loss: 0.0098 - val_mean_absolute_error: 0.0793
# Epoch 22/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0070 - mean_absolute_error: 0.0657 - val_loss: 0.0096 - val_mean_absolute_error: 0.0780
# Epoch 23/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0066 - mean_absolute_error: 0.0639 - val_loss: 0.0092 - val_mean_absolute_error: 0.0760
# Epoch 24/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0062 - mean_absolute_error: 0.0621 - val_loss: 0.0087 - val_mean_absolute_error: 0.0737
# Epoch 25/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0058 - mean_absolute_error: 0.0602 - val_loss: 0.0084 - val_mean_absolute_error: 0.0718
# Epoch 26/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0054 - mean_absolute_error: 0.0586 - val_loss: 0.0079 - val_mean_absolute_error: 0.0697
# Epoch 27/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0051 - mean_absolute_error: 0.0567 - val_loss: 0.0078 - val_mean_absolute_error: 0.0689
# Epoch 28/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0048 - mean_absolute_error: 0.0551 - val_loss: 0.0073 - val_mean_absolute_error: 0.0666
# Epoch 29/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0045 - mean_absolute_error: 0.0535 - val_loss: 0.0070 - val_mean_absolute_error: 0.0652
# Epoch 30/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_absolute_error: 0.0521 - val_loss: 0.0067 - val_mean_absolute_error: 0.0639
# Epoch 31/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0040 - mean_absolute_error: 0.0505 - val_loss: 0.0062 - val_mean_absolute_error: 0.0614
# Epoch 32/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0038 - mean_absolute_error: 0.0492 - val_loss: 0.0060 - val_mean_absolute_error: 0.0603
# Epoch 33/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0036 - mean_absolute_error: 0.0481 - val_loss: 0.0056 - val_mean_absolute_error: 0.0580
# Epoch 34/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0033 - mean_absolute_error: 0.0465 - val_loss: 0.0056 - val_mean_absolute_error: 0.0581
# Epoch 35/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0032 - mean_absolute_error: 0.0454 - val_loss: 0.0050 - val_mean_absolute_error: 0.0553
# Epoch 36/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0030 - mean_absolute_error: 0.0442 - val_loss: 0.0048 - val_mean_absolute_error: 0.0541
# Epoch 37/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0028 - mean_absolute_error: 0.0430 - val_loss: 0.0046 - val_mean_absolute_error: 0.0528
# Epoch 38/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0027 - mean_absolute_error: 0.0418 - val_loss: 0.0043 - val_mean_absolute_error: 0.0513
# Epoch 39/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0026 - mean_absolute_error: 0.0411 - val_loss: 0.0042 - val_mean_absolute_error: 0.0502
# Epoch 40/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0025 - mean_absolute_error: 0.0407 - val_loss: 0.0038 - val_mean_absolute_error: 0.0478
# Epoch 41/50
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0023 - mean_absolute_error: 0.0386 - val_loss: 0.0040 - val_mean_absolute_error: 0.0486
# Epoch 42/50
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0022 - mean_absolute_error: 0.0377 - val_loss: 0.0034 - val_mean_absolute_error: 0.0452
# Epoch 43/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0021 - mean_absolute_error: 0.0367 - val_loss: 0.0033 - val_mean_absolute_error: 0.0443
# Epoch 44/50
# 10/10 [==============================] - 0s 19ms/step - loss: 0.0019 - mean_absolute_error: 0.0355 - val_loss: 0.0032 - val_mean_absolute_error: 0.0432
# Epoch 45/50
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0018 - mean_absolute_error: 0.0345 - val_loss: 0.0029 - val_mean_absolute_error: 0.0416
# Epoch 46/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.0017 - mean_absolute_error: 0.0333 - val_loss: 0.0029 - val_mean_absolute_error: 0.0410
# Epoch 47/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0016 - mean_absolute_error: 0.0327 - val_loss: 0.0026 - val_mean_absolute_error: 0.0390
# Epoch 48/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0015 - mean_absolute_error: 0.0314 - val_loss: 0.0026 - val_mean_absolute_error: 0.0389
# Epoch 49/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0014 - mean_absolute_error: 0.0304 - val_loss: 0.0024 - val_mean_absolute_error: 0.0367
# Epoch 50/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0014 - mean_absolute_error: 0.0295 - val_loss: 0.0023 - val_mean_absolute_error: 0.0357

# %% [markdown]
# independent and dependent variables

# %%
# Define needed variables
tr_acc = history.history['mean_absolute_error']
tr_loss = history.history['loss']
val_acc = history.history['val_mean_absolute_error']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

# Plot training history
plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %% [markdown]
# Prediction

# %%
y_pred = model.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 7ms/step

# %%
from sklearn.metrics import r2_score

R2 = r2_score(y_test, y_pred)
print("R2 Score=",R2 )
# Out:
# R2 Score= 0.9425758351241463
